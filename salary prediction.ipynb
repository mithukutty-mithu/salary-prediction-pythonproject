# %%
import numpy as np
import pandas as pd
data = pd.read_csv("test.csv")
print(data)
# Out:
#       experience    country     education         languages  \
# 0             10  Singapore     Bachelors    JavaScript, Go
# 1             13        USA  Some College         PHP, Java
# 2             28      India  Some College    JavaScript, C#
# 3             16     Brazil     Bachelors  Ruby, JavaScript
# 4             20  Singapore           PhD        Java, Java
# ...          ...        ...           ...               ...
# 9995          16        USA     Bachelors         PHP, Rust
# 9996          29        USA       Masters  JavaScript, Ruby
# 9997           3        USA       Masters          C++, PHP
# 9998          35     Canada       Masters      Python, Rust
# 9999          28        USA       Masters       C++, Python
#
#                 frameworks company_size  salary_usd
# 0          Spring, Express         1-10       68491
# 1     Flask, Ruby on Rails       51-200      120045
# 2              Vue, Spring       51-200       87811
# ...

# %%
data.head(10)
# Out:
#    experience    country     education         languages  \
# 0          10  Singapore     Bachelors    JavaScript, Go
# 1          13        USA  Some College         PHP, Java
# 2          28      India  Some College    JavaScript, C#
# 3          16     Brazil     Bachelors  Ruby, JavaScript
# 4          20  Singapore           PhD        Java, Java
# 5           8      India     Bachelors           C#, PHP
# 6          28      India     Bachelors  JavaScript, Ruby
# 7          19    Germany       Masters  Ruby, JavaScript
# 8          17  Singapore           PhD       Swift, Rust
# 9          24     Canada       Masters         C++, Rust
#
#               frameworks company_size  salary_usd
# 0        Spring, Express         1-10       68491
# 1   Flask, Ruby on Rails       51-200      120045
# 2            Vue, Spring       51-200       87811
# 3          React, Spring     201-1000       99426
# 4       Laravel, Laravel     201-1000      108251
# ...

# %%
data.tail()
# Out:
#       experience country  education         languages       frameworks  \
# 9995          16     USA  Bachelors         PHP, Rust       Flask, Vue
# 9996          29     USA    Masters  JavaScript, Ruby      Spring, Vue
# 9997           3     USA    Masters          C++, PHP   Spring, Django
# 9998          35  Canada    Masters      Python, Rust  Spring, ASP.NET
# 9999          28     USA    Masters       C++, Python  ASP.NET, Django
#
#      company_size  salary_usd
# 9995        5000+      170146
# 9996       51-200      183539
# 9997         1-10      112739
# 9998       51-200      141723
# 9999         1-10      212411

# %%
data.describe()
# Out:
#          experience     salary_usd
# count  10000.000000   10000.000000
# mean      19.770100  131110.684200
# std       11.880234   46550.853186
# min        0.000000   12032.000000
# 25%        9.000000   97398.250000
# 50%       20.000000  129706.000000
# 75%       30.000000  164090.250000
# max       40.000000  280900.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   experience    10000 non-null  int64
#  1   country       10000 non-null  object
#  2   education     10000 non-null  object
#  3   languages     10000 non-null  object
#  4   frameworks    10000 non-null  object
#  5   company_size  10000 non-null  object
#  6   salary_usd    10000 non-null  int64
# dtypes: int64(2), object(5)
# memory usage: 547.0+ KB

# %%
data.describe()
# Out:
#          experience     salary_usd
# count  10000.000000   10000.000000
# mean      19.770100  131110.684200
# std       11.880234   46550.853186
# min        0.000000   12032.000000
# 25%        9.000000   97398.250000
# 50%       20.000000  129706.000000
# 75%       30.000000  164090.250000
# max       40.000000  280900.000000

# %%
missingvalue = data.isnull()
missingvalue
# Out:
#       experience  country  education  languages  frameworks  company_size  \
# 0          False    False      False      False       False         False
# 1          False    False      False      False       False         False
# 2          False    False      False      False       False         False
# 3          False    False      False      False       False         False
# 4          False    False      False      False       False         False
# ...          ...      ...        ...        ...         ...           ...
# 9995       False    False      False      False       False         False
# 9996       False    False      False      False       False         False
# 9997       False    False      False      False       False         False
# 9998       False    False      False      False       False         False
# 9999       False    False      False      False       False         False
#
#       salary_usd
# 0          False
# 1          False
# 2          False
# ...

# %%
missingvalue = data.isnull().sum()
missingvalue
# Out:
# experience      0
# country         0
# education       0
# languages       0
# frameworks      0
# company_size    0
# salary_usd      0
# dtype: int64

# %%
print(data.columns)
# Out:
# Index(['experience', 'country', 'education', 'languages', 'frameworks',
#        'company_size', 'salary_usd'],
#       dtype='object')

# %%
print("Experience mean:", data["experience"].mean())
print("Salary mean:", data["salary_usd"].mean())
# Out:
# Experience mean: 19.7701
# Salary mean: 131110.6842

# %%
print("Experience mean:", data["experience"].mean())
# Out:
# Experience mean: 19.7701

# %%
print("Salary mean:", data["salary_usd"].mean())
# Out:
# Salary mean: 131110.6842

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()

# %%
data["experience"] = label_encoder.fit_transform(data["experience"])
data["experience"]
# Out:
# 0       10
# 1       13
# 2       28
# 3       16
# 4       20
#         ..
# 9995    16
# 9996    29
# 9997     3
# 9998    35
# 9999    28
# Name: experience, Length: 10000, dtype: int64

# %%
data['Experience'].fillna(data['Experience'].mean(), inplace=True)
data['Salary'].fillna(data['Salary'].mean(), inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Experience'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 1
# ...

# %%
missingvalue = data.isnull().sum()
missingvalue
# Out:
# experience      0
# country         0
# education       0
# languages       0
# frameworks      0
# company_size    0
# salary_usd      0
# dtype: int64

# %%
data
# Out:
#       experience    country     education         languages  \
# 0             10  Singapore     Bachelors    JavaScript, Go
# 1             13        USA  Some College         PHP, Java
# 2             28      India  Some College    JavaScript, C#
# 3             16     Brazil     Bachelors  Ruby, JavaScript
# 4             20  Singapore           PhD        Java, Java
# ...          ...        ...           ...               ...
# 9995          16        USA     Bachelors         PHP, Rust
# 9996          29        USA       Masters  JavaScript, Ruby
# 9997           3        USA       Masters          C++, PHP
# 9998          35     Canada       Masters      Python, Rust
# 9999          28        USA       Masters       C++, Python
#
#                 frameworks company_size  salary_usd
# 0          Spring, Express         1-10       68491
# 1     Flask, Ruby on Rails       51-200      120045
# 2              Vue, Spring       51-200       87811
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("test.csv")

df.plot()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0, 1,2])
y = np.array([1, 2,3])

plt.plot(x, y)
plt.show()

# %%
x
# Out:
# array([0, 1, 2])

# %%
y
# Out:
# array([1, 2, 3])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
data.head()
# Out:
#    experience    country     education         languages  \
# 0          10  Singapore     Bachelors    JavaScript, Go
# 1          13        USA  Some College         PHP, Java
# 2          28      India  Some College    JavaScript, C#
# 3          16     Brazil     Bachelors  Ruby, JavaScript
# 4          20  Singapore           PhD        Java, Java
#
#              frameworks company_size  salary_usd
# 0       Spring, Express         1-10       68491
# 1  Flask, Ruby on Rails       51-200      120045
# 2           Vue, Spring       51-200       87811
# 3         React, Spring     201-1000       99426
# 4      Laravel, Laravel     201-1000      108251

# %%
X_test
# Out:
# array([0])

# %%
y_test
# Out:
# array([1])

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

# %%
import joblib

joblib.dump(model, 'evebatch.pkl')
# Out:
# ['evebatch.pkl']
